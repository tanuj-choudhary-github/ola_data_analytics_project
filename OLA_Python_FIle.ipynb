# %%
import pandas as pd

df = pd.read_csv("C:/Users/267206/Desktop/Data_Analyst_Projects/OLA_Data_Analytics_Project/ola_excel_data.csv", low_memory=False)

# %%
df.head()
# Out:
#                   Date      Time     Booking_ID        Booking_Status  \
# 0  2024-07-26 14:00:00  14:00:00  CNR7153255142    Canceled by Driver
# 1  2024-07-25 22:20:00  22:20:00  CNR2940424040               Success
# 2  2024-07-30 19:59:00  19:59:00  CNR2982357879               Success
# 3   2024-07-22 3:15:00  03:15:00  CNR2395710036  Canceled by Customer
# 4   2024-07-02 9:02:00  09:02:00  CNR1797421769               Success
#
#   Customer_ID Vehicle_Type Pickup_Location Drop_Location  V_TAT  C_TAT  ...  \
# 0   CID713523  Prime Sedan     Tumkur Road      RT Nagar    NaN    NaN  ...
# 1   CID225428         Bike     Magadi Road       Varthur  203.0   30.0  ...
# 2   CID270156    Prime SUV   Sahakar Nagar       Varthur  238.0  130.0  ...
# 3   CID581320        eBike      HSR Layout   Vijayanagar    NaN    NaN  ...
# 4   CID939555         Mini     Rajajinagar   Chamarajpet  252.0   80.0  ...
#
#        Canceled_Rides_by_Driver Incomplete_Rides Incomplete_Rides_Reason  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 103024 entries, 0 to 103023
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        40539 non-null  str
#  1   Time                        40539 non-null  str
#  2   Booking_ID                  40539 non-null  str
#  3   Booking_Status              40539 non-null  str
#  4   Customer_ID                 40539 non-null  str
#  5   Vehicle_Type                40539 non-null  str
#  6   Pickup_Location             40539 non-null  str
#  7   Drop_Location               40539 non-null  str
#  8   V_TAT                       25207 non-null  float64
#  9   C_TAT                       25207 non-null  float64
#  10  Canceled_Rides_by_Customer  4079 non-null   str
#  11  Canceled_Rides_by_Driver    7212 non-null   str
#  12  Incomplete_Rides            25207 non-null  str
#  13  Incomplete_Rides_Reason     1542 non-null   str
# ...

# %%
df.describe(include='all')
# Out:
#                       Date      Time     Booking_ID Booking_Status  \
# count                40539     40539          40539          40539
# unique               26347      1440          40539              4
# top     2024-07-19 8:13:00  10:22:00  CNR7153255142        Success
# freq                     7        47              1          25207
# mean                   NaN       NaN            NaN            NaN
# std                    NaN       NaN            NaN            NaN
# min                    NaN       NaN            NaN            NaN
# 25%                    NaN       NaN            NaN            NaN
# 50%                    NaN       NaN            NaN            NaN
# 75%                    NaN       NaN            NaN            NaN
# max                    NaN       NaN            NaN            NaN
#
#        Customer_ID Vehicle_Type Pickup_Location Drop_Location         V_TAT  \
# count        40539        40539           40539         40539  25207.000000
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'Booking_ID', 'Booking_Status', 'Customer_ID',
#        'Vehicle_Type', 'Pickup_Location', 'Drop_Location', 'V_TAT', 'C_TAT',
#        'Canceled_Rides_by_Customer', 'Canceled_Rides_by_Driver',
#        'Incomplete_Rides', 'Incomplete_Rides_Reason', 'Booking_Value',
#        'Payment_Method', 'Ride_Distance', 'Driver_Ratings', 'Customer_Rating',
#        'Vehicle Images', 'Unnamed: 20'],
#       dtype='str')

# %%
# Step 1: Connect to MySQL
# Replace placeholders with your actual details

from sqlalchemy import create_engine
from urllib.parse import quote_plus

username = "root"                 # MySQL default user
password = quote_plus("Tanuj@2001")  # the password you set (encoded because of @)
host = "localhost"                # if running locally
port = "3306"                     # default MySQL port
database = "ola"   # the database you created in MySQL

engine = create_engine(
    f"mysql+mysqlconnector://{username}:{password}@{host}:{port}/{database}"
)

# Step 2: Load DataFrame into MySQL
table_name = "bookings"   # choose any table name

df.to_sql(table_name, engine, if_exists="replace", index=False)

print(f"Data successfully loaded into table '{table_name}' in database '{database}'.")
# Out:
# Data successfully loaded into table 'bookings' in database 'ola'.
